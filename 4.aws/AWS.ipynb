# %%
#AWS Services

''' 
Q) Explain the use cases for AWS S3, RDS, Redshift, and EMR.
Q) How would you secure data in S3? Discuss encryption options.
Q) Describe how you would set up and configure an ETL pipeline using AWS services.
Q) What is AWS Lambda, and how would you use it in a data engineering context?

'''

#Data Warehousing & Analytics:
'''
Q) Explain the differences between Amazon Redshift and Amazon RDS.
Q) How would you optimize query performance in Amazon Redshift?
Q) Discuss the best practices for managing and optimizing an AWS EMR cluster.
'''

# Problem Solving:
'''
Q) Design a data pipeline in AWS that ingests streaming data into S3, processes it with EMR, and loads it into Redshift.
Q) How would you migrate an on-premises data warehouse to AWS Redshift?
'''

# %%
### **S3 (Simple Storage Service)**

'''
1. **How would you design a data lake architecture using S3? What best practices would you follow?**
2. **Explain S3 bucket policies and how they differ from IAM policies. When would you use each?**
3. **How can you ensure data security and compliance in S3?**
4. **What strategies can you implement to optimize costs when storing large datasets in S3?**

'''
### **Glue**
'''
1. **How would you use AWS Glue to automate ETL workflows for a large dataset?**
2. **Can you explain the difference between Glue Jobs, Crawlers, and Data Catalog?**
3. **Describe how AWS Glue integrates with other AWS services like S3, Athena, and Redshift.**
4. **How would you handle schema evolution in AWS Glue when dealing with semi-structured data?**

'''

### **Lambda**
'''
1. **What are the use cases for AWS Lambda in a data engineering pipeline?**
2. **How would you manage cold start issues in Lambda functions for real-time data processing?**
3. **Explain how you can use AWS Lambda to trigger ETL jobs in Glue or data queries in Athena.**
4. **Discuss the best practices for error handling and retries in AWS Lambda functions.**
'''

### **Athena**
''''
1. **How do you optimize query performance in AWS Athena when working with large datasets?**
2. **Explain the process of partitioning data in S3 and how it benefits Athena queries.**
3. **What are the cost implications of running queries in Athena, and how can you minimize them?**
4. **How would you integrate Athena with QuickSight for real-time data visualization?**

'''

### **QuickSight**
'''
1. **Describe the process of connecting QuickSight to various data sources like S3, Redshift, and RDS.**
2. **How do you handle data refresh and synchronization in QuickSight dashboards?**
3. **What are some best practices for securing data in QuickSight reports and dashboards?**
4. **How would you optimize performance in QuickSight when dealing with large datasets?**

'''

### **EventBridge**
'''
    1. **What role does EventBridge play in an event-driven architecture? How would you implement it in a data pipeline?**
    2. **Explain how EventBridge can be used to trigger AWS Glue jobs or Lambda functions.**
    3. **How can you ensure the reliability and scalability of events in EventBridge?**
    4. **Discuss the use cases for EventBridge in automating workflows across multiple AWS services.**
'''
